# %%
# !pip install imutils opencv-python face_recognition numpy
# Out:
# Collecting imutils
#   Using cached imutils-0.5.4-py3-none-any.whl
# Collecting opencv-python
#   Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting numpy
#   Downloading numpy-1.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 240.3 kB/s eta 0:00:001m565.5 kB/s eta 0:00:01
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Collecting Click>=6.0 (from face_recognition)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dlib>=19.7 (from face_recognition)
#   Using cached dlib-19.24.2-cp310-cp310-linux_x86_64.whl
# Collecting Pillow (from face_recognition)
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Downloading numpy-1.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 839.9 kB/s eta 0:00:001m5.4 MB/s eta 0:00:01
# Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 436.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: imutils, face-recognition-models, dlib, Pillow, numpy, Click, opencv-python, face_recognition
# Successfully installed Click-8.1.7 Pillow-10.1.0 dlib-19.24.2 face-recognition-models-0.3.0 face_recognition-1.3.0 imutils-0.5.4 numpy-1.26.1 opencv-python-4.8.1.78

# %%
import imutils
import time
from imutils import face_utils
import dlib
import cv2
import face_recognition 
import numpy as np
import traceback
import numpy as np
import os
import numpy as np
import traceback

# %%
# path imagenes folder
path_images = "faces"

# threshold 
threshold = 0.53

# %%
def get_features(img,box):
    features = face_recognition.face_encodings(img,box)
    return features

def compare_faces(face_encodings,db_features,db_names):
    match_name = []
    names_temp = db_names
    Feats_temp = db_features  

    for face_encoding in face_encodings:
        dist = face_recognition.face_distance(Feats_temp,face_encoding)
        index = np.argmin(dist)
        if dist[index] <= threshold:
            
            match_name = match_name + [names_temp[index]]
        else:
            match_name = match_name + ["unknown"]
    return match_name, dist[index]

# %%
class rec():
    def __init__(self):
        
        print("Creating DataBase ...")
        self.db_names, self.db_features = load_images_to_database()
        print("DataBase created ...")

    def recognize_face(self,im):
    
        box_faces = face_recognition.face_locations(im)
        actual_features = get_features(im,box_faces)

        # conditional in case no face is detected
        if  not box_faces:
            res = {
                'status':'ok',
                'faces':[],
                'names':[],
                'dist face':[]}
            return res
        else:
            if not self.db_names:
                res = {
                    'status':'ok',
                    'faces':box_faces,
                    'names':['unknow']*len(box_faces),
                    'dist face': face_dis}
                return res
            else:
                # (continued) extract features
                actual_features = get_features(im,box_faces)
                face_dis= compare_faces(actual_features,self.db_features,self.db_names)[1]
                # compare actual_features with those stored in the database
                match_names = compare_faces(actual_features,self.db_features,self.db_names)[0]

                # save
                res = {
                    'status':'ok',
                    'faces':box_faces,
                    'names':match_names,
                    'dist face': face_dis}
                return res


def bounding_box(img,box,match_name=[]):
    for i in np.arange(len(box)):
        y0,x1,y1,x0 = box[i]
        img = cv2.rectangle(img,
                      (x0,y0),
                      (x1,y1),
                      (0,255,0),3);
        if not match_name:
            continue
        else:
            cv2.putText(img, match_name[i], (x0, y0-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)
    return img

# %%
def load_images_to_database():
    list_images = os.listdir(path_images)
    # I filter the files that are not images
    list_images = [File for File in list_images if File.endswith(('.jpg','.jpeg','JPEG','.png'))]

    name = []
    Feats = []

    # image ingest
    for file_name in list_images:
        im = cv2.imread(path_images+os.sep+file_name)

        # I get the features of the face
        box_face = face_recognition.face_locations(im)
        
        feat = get_features(im,box_face)
        if len(feat)!=1:
            '''
            this means that there are no faces or there is more than one face
            '''
            continue
        else:
            
            # insert the new features to the database
            
            new_name = file_name.split(".")[0]
            new_name=new_name.split("_")[0]
            if new_name == "":
                continue
            name.append(new_name)
            if len(Feats)==0:
                Feats = np.frombuffer(feat[0], dtype=np.float64)
            else:
                Feats = np.vstack((Feats,np.frombuffer(feat[0], dtype=np.float64)))
    return name, Feats

# %%
cap=cv2.VideoCapture(0)
recognizer=rec()
while True:
    (grabbed, image)=cap.read()
    if not grabbed:
        break
#     image=imutils.resize(image,720)
    star_time = time.time()
    ref = recognizer.recognize_face(image)
    print(ref)
    image = bounding_box(image,ref["faces"],ref["names"])

    end_time = time.time() - star_time    
    FPS = 1/end_time
    cv2.putText(image,f"FPS: {round(FPS,3)}",(10,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
    cv2.imshow("Detection",image)
    if cv2.waitKey(1) &0xFF == ord('q'):
        
            break
    
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Creating DataBase ...
# DataBase created ...
# {'status': 'ok', 'faces': [(253, 425, 408, 270)], 'names': ['unknown'], 'dist face': 0.5396418334350186}
# {'status': 'ok', 'faces': [(253, 425, 408, 270)], 'names': ['unknown'], 'dist face': 0.5693251317633332}
# {'status': 'ok', 'faces': [(253, 425, 408, 270)], 'names': ['unknown'], 'dist face': 0.5683535746166318}
# {'status': 'ok', 'faces': [(242, 428, 428, 242)], 'names': ['reby'], 'dist face': 0.5093628671792965}
# {'status': 'ok', 'faces': [(242, 407, 428, 221)], 'names': ['unknown'], 'dist face': 0.5744508725623112}
# {'status': 'ok', 'faces': [(242, 407, 428, 221)], 'names': ['reby'], 'dist face': 0.5225333060279727}
# {'status': 'ok', 'faces': [(242, 407, 428, 221)], 'names': ['unknown'], 'dist face': 0.5704733795509103}
# {'status': 'ok', 'faces': [(253, 425, 408, 270)], 'names': ['unknown'], 'dist face': 0.5871679782022196}
# {'status': 'ok', 'faces': [(253, 442, 408, 287)], 'names': ['unknown'], 'dist face': 0.5361991216635583}
# {'status': 'ok', 'faces': [(253, 442, 408, 287)], 'names': ['unknown'], 'dist face': 0.5388973924202897}
# {'status': 'ok', 'faces': [(253, 442, 408, 287)], 'names': ['unknown'], 'dist face': 0.5424769301586971}
# {'status': 'ok', 'faces': [(242, 448, 428, 262)], 'names': ['unknown'], 'dist face': 0.5899897312436819}
# {'status': 'ok', 'faces': [(288, 408, 442, 253)], 'names': ['unknown'], 'dist face': 0.544333874724257}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(36, 469, 222, 283)], 'names': ['unknown'], 'dist face': 0.5670052688587192}
# {'status': 'ok', 'faces': [(98, 448, 284, 262)], 'names': ['reby'], 'dist face': 0.4683955515195077}
# {'status': 'ok', 'faces': [(98, 448, 284, 262)], 'names': ['reby'], 'dist face': 0.47458299967288275}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(160, 469, 345, 283)], 'names': ['reby'], 'dist face': 0.497292901237575}
# {'status': 'ok', 'faces': [(139, 469, 325, 283)], 'names': ['reby'], 'dist face': 0.4439243462251894}
# {'status': 'ok', 'faces': [(139, 448, 325, 262)], 'names': ['reby'], 'dist face': 0.4747881710832566}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(192, 489, 415, 266)], 'names': ['unknown'], 'dist face': 0.6319310388916204}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(142, 513, 365, 291)], 'names': ['unknown'], 'dist face': 0.5455597810846483}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(167, 489, 390, 266)], 'names': ['reby'], 'dist face': 0.5127749806629572}
# {'status': 'ok', 'faces': [(192, 489, 415, 266)], 'names': ['reby'], 'dist face': 0.4948605322307462}
# {'status': 'ok', 'faces': [(192, 489, 415, 266)], 'names': ['reby'], 'dist face': 0.5122777532722228}
# {'status': 'ok', 'faces': [(192, 513, 415, 291)], 'names': ['reby'], 'dist face': 0.5005177365524652}
# {'status': 'ok', 'faces': [(192, 513, 415, 291)], 'names': ['reby'], 'dist face': 0.4895659359925375}
# {'status': 'ok', 'faces': [(222, 510, 407, 324)], 'names': ['reby'], 'dist face': 0.4909071666959409}
# {'status': 'ok', 'faces': [(192, 513, 415, 291)], 'names': ['reby'], 'dist face': 0.47193107698669334}
# {'status': 'ok', 'faces': [(192, 513, 415, 291)], 'names': ['reby'], 'dist face': 0.4765744030731651}
# {'status': 'ok', 'faces': [(222, 469, 407, 283)], 'names': ['reby'], 'dist face': 0.43406230150641234}
# {'status': 'ok', 'faces': [(222, 489, 407, 304)], 'names': ['reby'], 'dist face': 0.4324941875056195}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(201, 510, 387, 324)], 'names': ['unknown'], 'dist face': 0.5345575035671228}
# {'status': 'ok', 'faces': [(201, 510, 387, 324)], 'names': ['unknown'], 'dist face': 0.5326983797571754}
# {'status': 'ok', 'faces': [(201, 510, 387, 324)], 'names': ['reby'], 'dist face': 0.5010837040658701}
# {'status': 'ok', 'faces': [(201, 510, 387, 324)], 'names': ['reby'], 'dist face': 0.511366997920536}
# {'status': 'ok', 'faces': [(201, 510, 387, 324)], 'names': ['reby'], 'dist face': 0.4739707708840025}
# {'status': 'ok', 'faces': [(201, 510, 387, 324)], 'names': ['unknown'], 'dist face': 0.5513518743823888}
# {'status': 'ok', 'faces': [(222, 510, 407, 324)], 'names': ['unknown'], 'dist face': 0.5372987745373247}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['reby'], 'dist face': 0.4775673425539573}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['reby'], 'dist face': 0.47184509106446404}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['reby'], 'dist face': 0.5053528172570909}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['reby'], 'dist face': 0.5148842075090445}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['reby'], 'dist face': 0.50364613163232}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['unknown'], 'dist face': 0.5394534043819066}
# {'status': 'ok', 'faces': [(201, 531, 387, 345)], 'names': ['reby'], 'dist face': 0.528450302336559}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(360, 498, 412, 446)], 'names': ['unknown'], 'dist face': 0.7293482418310709}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(284, 469, 469, 283)], 'names': ['unknown'], 'dist face': 0.5348242637985462}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}

# %%
q
