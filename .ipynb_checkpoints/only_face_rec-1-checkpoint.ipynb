# %%
import imutils
import time
from imutils import face_utils
import dlib
import cv2
import face_recognition 
import numpy as np
import traceback
import numpy as np
import os
import numpy as np
import traceback

# %%
# path imagenes folder
path_images = "pictures"

# threshold 
threshold = 0.53

# %%
def get_features(img,box):
    features = face_recognition.face_encodings(img,box)
    return features

def compare_faces(face_encodings,db_features,db_names):
    match_name = []
    names_temp = db_names
    Feats_temp = db_features  

    for face_encoding in face_encodings:
        dist = face_recognition.face_distance(Feats_temp,face_encoding)
        index = np.argmin(dist)
        if dist[index] <= threshold:
            
            match_name = match_name + [names_temp[index]]
        else:
            match_name = match_name + ["unknown"]
    return match_name, dist[index]

# %%
class rec():
    def __init__(self):
        
        print("Creating DataBase ...")
        self.db_names, self.db_features = load_images_to_database()
        print("DataBase created ...")

    def recognize_face(self,im):
    
        box_faces = face_recognition.face_locations(im)
        actual_features = get_features(im,box_faces)

        # conditional in case no face is detected
        if  not box_faces:
            res = {
                'status':'ok',
                'faces':[],
                'names':[],
                'dist face':[]}
            return res
        else:
            if not self.db_names:
                res = {
                    'status':'ok',
                    'faces':box_faces,
                    'names':['unknow']*len(box_faces),
                    'dist face': face_dis}
                return res
            else:
                # (continued) extract features
                actual_features = get_features(im,box_faces)
                face_dis= compare_faces(actual_features,self.db_features,self.db_names)[1]
                # compare actual_features with those stored in the database
                match_names = compare_faces(actual_features,self.db_features,self.db_names)[0]

                # save
                res = {
                    'status':'ok',
                    'faces':box_faces,
                    'names':match_names,
                    'dist face': face_dis}
                return res


def bounding_box(img,box,match_name=[]):
    for i in np.arange(len(box)):
        y0,x1,y1,x0 = box[i]
        img = cv2.rectangle(img,
                      (x0,y0),
                      (x1,y1),
                      (0,255,0),3);
        if not match_name:
            continue
        else:
            cv2.putText(img, match_name[i], (x0, y0-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)
    return img

# %%
def load_images_to_database():
    list_images = os.listdir(path_images)
    # I filter the files that are not images
    list_images = [File for File in list_images if File.endswith(('.jpg','.jpeg','JPEG','.png'))]

    name = []
    Feats = []

    # image ingest
    for file_name in list_images:
        im = cv2.imread(path_images+os.sep+file_name)

        # I get the features of the face
        box_face = face_recognition.face_locations(im)
        
        feat = get_features(im,box_face)
        if len(feat)!=1:
            '''
            this means that there are no faces or there is more than one face
            '''
            continue
        else:
            
            # insert the new features to the database
            
            new_name = file_name.split(".")[0]
            new_name=new_name.split("_")[0]
            if new_name == "":
                continue
            name.append(new_name)
            if len(Feats)==0:
                Feats = np.frombuffer(feat[0], dtype=np.float64)
            else:
                Feats = np.vstack((Feats,np.frombuffer(feat[0], dtype=np.float64)))
    return name, Feats

# %%
cap=cv2.VideoCapture(0)
recognizer=rec()
while True:
    (grabbed, image)=cap.read()
    if not grabbed:
        break
#     image=imutils.resize(image,720)
    star_time = time.time()
    ref = recognizer.recognize_face(image)
    print(ref)
    image = bounding_box(image,ref["faces"],ref["names"])

    end_time = time.time() - star_time    
    FPS = 1/end_time
    cv2.putText(image,f"FPS: {round(FPS,3)}",(10,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
    cv2.imshow("Detection",image)
    if cv2.waitKey(1) &0xFF == ord('q'):
        
            break
    
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Creating DataBase ...
# DataBase created ...
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.4703789191099751}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.47590112040853466}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.5151272532688578}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.5143592795888285}
# {'status': 'ok', 'faces': [(236, 390, 391, 236)], 'names': ['manaf'], 'dist face': 0.5101697627200605}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(236, 390, 391, 236)], 'names': ['manaf'], 'dist face': 0.4809412469827652}
# {'status': 'ok', 'faces': [(219, 390, 374, 236)], 'names': ['manaf'], 'dist face': 0.4756391888079107}
# {'status': 'ok', 'faces': [(219, 390, 374, 236)], 'names': ['manaf'], 'dist face': 0.5063583803148126}
# {'status': 'ok', 'faces': [(219, 390, 374, 236)], 'names': ['manaf'], 'dist face': 0.5192724647229525}
# {'status': 'ok', 'faces': [(239, 368, 368, 239)], 'names': ['unknown'], 'dist face': 0.5598861072609145}
# {'status': 'ok', 'faces': [(236, 356, 391, 201)], 'names': ['manaf'], 'dist face': 0.49437434104007366}
# {'status': 'ok', 'faces': [(239, 339, 368, 210)], 'names': ['manaf'], 'dist face': 0.510745464438927}
# {'status': 'ok', 'faces': [(219, 356, 374, 201)], 'names': ['manaf'], 'dist face': 0.49913261461105257}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(236, 356, 391, 201)], 'names': ['manaf'], 'dist face': 0.5179559666816314}
# {'status': 'ok', 'faces': [(236, 356, 391, 201)], 'names': ['manaf'], 'dist face': 0.5114294018334336}
# {'status': 'ok', 'faces': [(236, 356, 391, 201)], 'names': ['manaf'], 'dist face': 0.518222575755198}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.500190669815738}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.49092837657880356}
# {'status': 'ok', 'faces': [(236, 373, 391, 218)], 'names': ['manaf'], 'dist face': 0.4421667470799905}
# {'status': 'ok', 'faces': [(236, 356, 391, 201)], 'names': ['unknown'], 'dist face': 0.5400506093744457}
# {'status': 'ok', 'faces': [(219, 339, 374, 184)], 'names': ['unknown'], 'dist face': 0.5387732261314444}
# {'status': 'ok', 'faces': [(239, 311, 368, 182)], 'names': ['manaf'], 'dist face': 0.47637088501506447}
# {'status': 'ok', 'faces': [(254, 311, 383, 182)], 'names': ['manaf'], 'dist face': 0.4607772921540821}
# {'status': 'ok', 'faces': [(254, 296, 383, 167)], 'names': ['manaf'], 'dist face': 0.4848346184679642}
# {'status': 'ok', 'faces': [(254, 268, 383, 139)], 'names': ['manaf'], 'dist face': 0.5066036574169186}
# {'status': 'ok', 'faces': [(254, 253, 383, 124)], 'names': ['manaf'], 'dist face': 0.5208624415194985}
# {'status': 'ok', 'faces': [(254, 239, 383, 110)], 'names': ['manaf'], 'dist face': 0.4730233969014021}
# {'status': 'ok', 'faces': [(236, 236, 391, 81)], 'names': ['manaf'], 'dist face': 0.5084919192763824}
# {'status': 'ok', 'faces': [(236, 236, 391, 81)], 'names': ['unknown'], 'dist face': 0.5519225143268115}
# {'status': 'ok', 'faces': [(236, 236, 391, 81)], 'names': ['unknown'], 'dist face': 0.5453740746284464}
# {'status': 'ok', 'faces': [(236, 253, 391, 98)], 'names': ['manaf'], 'dist face': 0.504576385442227}
# {'status': 'ok', 'faces': [(236, 253, 391, 98)], 'names': ['manaf'], 'dist face': 0.5069669281175168}
# {'status': 'ok', 'faces': [(236, 253, 391, 98)], 'names': ['manaf'], 'dist face': 0.4863717103978398}
# {'status': 'ok', 'faces': [(236, 236, 391, 81)], 'names': ['manaf'], 'dist face': 0.49693114815881706}
# {'status': 'ok', 'faces': [(268, 196, 397, 67)], 'names': ['manaf'], 'dist face': 0.5054483382850654}
# {'status': 'ok', 'faces': [(268, 196, 397, 67)], 'names': ['unknown'], 'dist face': 0.5593472494753723}
# {'status': 'ok', 'faces': [(283, 199, 390, 91)], 'names': ['unknown'], 'dist face': 0.5542783215598392}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['manaf'], 'dist face': 0.502832885507589}
# {'status': 'ok', 'faces': [(268, 225, 397, 96)], 'names': ['unknown'], 'dist face': 0.5440694986330169}
# {'status': 'ok', 'faces': [(268, 239, 397, 110)], 'names': ['manaf'], 'dist face': 0.5132021823441454}
# {'status': 'ok', 'faces': [(268, 239, 397, 110)], 'names': ['unknown'], 'dist face': 0.5720853684122442}
# {'status': 'ok', 'faces': [(268, 239, 397, 110)], 'names': ['unknown'], 'dist face': 0.593576835999644}
# {'status': 'ok', 'faces': [(268, 239, 397, 110)], 'names': ['manaf'], 'dist face': 0.5069340324890129}
# {'status': 'ok', 'faces': [(254, 239, 383, 110)], 'names': ['manaf'], 'dist face': 0.5160217187624603}
# {'status': 'ok', 'faces': [(254, 253, 383, 124)], 'names': ['unknown'], 'dist face': 0.5325840615988758}
# {'status': 'ok', 'faces': [(268, 239, 397, 110)], 'names': ['manaf'], 'dist face': 0.49239665070053446}
# {'status': 'ok', 'faces': [(268, 253, 397, 124)], 'names': ['unknown'], 'dist face': 0.5415700700655532}
# {'status': 'ok', 'faces': [(268, 268, 397, 139)], 'names': ['unknown'], 'dist face': 0.5736872201291319}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(268, 282, 397, 153)], 'names': ['unknown'], 'dist face': 0.5661364549484919}
# {'status': 'ok', 'faces': [(268, 268, 397, 139)], 'names': ['manaf'], 'dist face': 0.489309749731874}
# {'status': 'ok', 'faces': [(283, 235, 390, 127), (375, 633, 464, 544)], 'names': ['unknown', 'unknown'], 'dist face': 0.5982316186576714}
# {'status': 'ok', 'faces': [(282, 239, 411, 110), (365, 640, 454, 554)], 'names': ['manaf', 'unknown'], 'dist face': 0.6159293928428529}
# {'status': 'ok', 'faces': [(282, 239, 411, 110), (378, 640, 453, 569)], 'names': ['manaf', 'unknown'], 'dist face': 0.5835944519558675}
# {'status': 'ok', 'faces': [(268, 253, 397, 124), (365, 640, 454, 554)], 'names': ['unknown', 'unknown'], 'dist face': 0.6668232239532649}
# {'status': 'ok', 'faces': [(295, 247, 402, 139), (365, 640, 454, 554)], 'names': ['manaf', 'unknown'], 'dist face': 0.6288482324371135}
# {'status': 'ok', 'faces': [(268, 268, 397, 139), (365, 633, 454, 544)], 'names': ['manaf', 'unknown'], 'dist face': 0.6364199904417329}
# {'status': 'ok', 'faces': [(375, 633, 464, 544)], 'names': ['unknown'], 'dist face': 0.6320400533064875}
# {'status': 'ok', 'faces': [(387, 640, 461, 569), (283, 282, 390, 175)], 'names': ['unknown', 'manaf'], 'dist face': 0.49720966948996814}
# {'status': 'ok', 'faces': [(268, 282, 397, 153), (387, 640, 461, 569)], 'names': ['unknown', 'unknown'], 'dist face': 0.5972073786777852}
# {'status': 'ok', 'faces': [(282, 268, 411, 139)], 'names': ['unknown'], 'dist face': 0.5309046809151851}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(282, 282, 411, 153)], 'names': ['unknown'], 'dist face': 0.530322750313739}
# {'status': 'ok', 'faces': [(282, 282, 411, 153)], 'names': ['manaf'], 'dist face': 0.5219657366076481}
# {'status': 'ok', 'faces': [(268, 282, 397, 153)], 'names': ['manaf'], 'dist face': 0.4600677285908407}
# {'status': 'ok', 'faces': [(268, 268, 397, 139)], 'names': ['manaf'], 'dist face': 0.5149671776630619}
# {'status': 'ok', 'faces': [(268, 268, 397, 139)], 'names': ['manaf'], 'dist face': 0.525584332805744}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(268, 239, 397, 110)], 'names': ['unknown'], 'dist face': 0.5720777731428097}
# {'status': 'ok', 'faces': [(253, 218, 408, 64)], 'names': ['unknown'], 'dist face': 0.5951710963621502}
# {'status': 'ok', 'faces': [(268, 182, 397, 53)], 'names': ['unknown'], 'dist face': 0.5711276735463364}
# {'status': 'ok', 'faces': [(236, 184, 391, 29)], 'names': ['unknown'], 'dist face': 0.587437533700239}
# {'status': 'ok', 'faces': [(236, 167, 391, 12)], 'names': ['unknown'], 'dist face': 0.5343042557896526}
# {'status': 'ok', 'faces': [(236, 184, 391, 29), (387, 640, 461, 577)], 'names': ['unknown', 'unknown'], 'dist face': 0.6159546989091004}
# {'status': 'ok', 'faces': [(271, 175, 378, 67)], 'names': ['unknown'], 'dist face': 0.5383884396080114}
# {'status': 'ok', 'faces': [(387, 640, 461, 577)], 'names': ['unknown'], 'dist face': 0.6620432846137856}
# {'status': 'ok', 'faces': [(387, 640, 461, 577), (285, 195, 375, 106)], 'names': ['unknown', 'manaf'], 'dist face': 0.5265176246021052}
# {'status': 'ok', 'faces': [(283, 235, 390, 127), (387, 640, 461, 577)], 'names': ['manaf', 'unknown'], 'dist face': 0.6290616847389747}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['unknown'], 'dist face': 0.5491444670900549}
# {'status': 'ok', 'faces': [(268, 239, 397, 110), (375, 640, 464, 563)], 'names': ['unknown', 'unknown'], 'dist face': 0.5674381290493221}
# {'status': 'ok', 'faces': [(283, 235, 390, 127), (375, 640, 464, 563)], 'names': ['unknown', 'unknown'], 'dist face': 0.5607053524575907}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.46629870562297426}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.49515202661714525}
# {'status': 'ok', 'faces': [(268, 225, 397, 96)], 'names': ['unknown'], 'dist face': 0.5466659980715636}
# {'status': 'ok', 'faces': [(268, 225, 397, 96)], 'names': ['manaf'], 'dist face': 0.5205941855685574}
# {'status': 'ok', 'faces': [(295, 199, 402, 91)], 'names': ['manaf'], 'dist face': 0.5172948133638724}
# {'status': 'ok', 'faces': [(283, 211, 390, 103), (387, 640, 461, 577)], 'names': ['manaf', 'unknown'], 'dist face': 0.5520613220813482}
# {'status': 'ok', 'faces': [(283, 223, 390, 115), (387, 640, 461, 577)], 'names': ['manaf', 'unknown'], 'dist face': 0.6024694723280147}
# {'status': 'ok', 'faces': [(295, 235, 402, 127)], 'names': ['manaf'], 'dist face': 0.5104368588839185}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['unknown'], 'dist face': 0.5423113878492436}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['unknown'], 'dist face': 0.5787468174900735}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['manaf'], 'dist face': 0.5045643646078444}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['unknown'], 'dist face': 0.5818923867056804}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['unknown'], 'dist face': 0.5547517562435619}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5213387453329549}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['unknown'], 'dist face': 0.5571416131548692}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5171829448079717}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5189633865189568}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5258998244191049}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['unknown'], 'dist face': 0.5554319035272625}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['manaf'], 'dist face': 0.4858711656517978}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5075886265035652}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['manaf'], 'dist face': 0.5132404930889197}
# {'status': 'ok', 'faces': [(282, 239, 411, 110)], 'names': ['manaf'], 'dist face': 0.5250549841282744}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['unknown'], 'dist face': 0.5316074406152358}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['unknown'], 'dist face': 0.5344554516207152}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5049463790720394}
# {'status': 'ok', 'faces': [(295, 223, 402, 115), (368, 640, 480, 540)], 'names': ['unknown', 'unknown'], 'dist face': 0.6286155905716445}
# {'status': 'ok', 'faces': [(282, 239, 411, 110)], 'names': ['unknown'], 'dist face': 0.5355043959793978}
# {'status': 'ok', 'faces': [(283, 235, 390, 127)], 'names': ['manaf'], 'dist face': 0.47009632663512513}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.5177309378860501}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.49751319731735255}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['manaf'], 'dist face': 0.5280693139993011}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['unknown'], 'dist face': 0.5643300169242969}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['unknown'], 'dist face': 0.5404946625617267}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['manaf'], 'dist face': 0.4669213285859947}
# {'status': 'ok', 'faces': [(283, 211, 390, 103), (47, 640, 202, 511)], 'names': ['manaf', 'unknown'], 'dist face': 0.5980751451039911}
# {'status': 'ok', 'faces': [(283, 211, 390, 103)], 'names': ['unknown'], 'dist face': 0.5367228108110982}
# {'status': 'ok', 'faces': [(283, 211, 390, 103), (47, 640, 202, 511)], 'names': ['manaf', 'unknown'], 'dist face': 0.5994022990687996}
# {'status': 'ok', 'faces': [(283, 211, 390, 103), (47, 640, 202, 511)], 'names': ['manaf', 'unknown'], 'dist face': 0.5836269167322715}
# {'status': 'ok', 'faces': [(283, 199, 390, 91), (47, 640, 202, 511)], 'names': ['unknown', 'unknown'], 'dist face': 0.5953178267991404}
# {'status': 'ok', 'faces': [(283, 199, 390, 91)], 'names': ['manaf'], 'dist face': 0.5200862537902265}
# {'status': 'ok', 'faces': [(283, 199, 390, 91)], 'names': ['unknown'], 'dist face': 0.5538487698248227}
# {'status': 'ok', 'faces': [(283, 199, 390, 91)], 'names': ['manaf'], 'dist face': 0.5029695126121626}
# {'status': 'ok', 'faces': [(283, 199, 390, 91), (368, 640, 480, 540)], 'names': ['manaf', 'unknown'], 'dist face': 0.6212667678651959}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['manaf'], 'dist face': 0.4835091975049414}
# {'status': 'ok', 'faces': [(295, 211, 402, 103), (387, 640, 461, 569)], 'names': ['manaf', 'unknown'], 'dist face': 0.5721707648271865}
# {'status': 'ok', 'faces': [(295, 211, 402, 103), (375, 640, 464, 563)], 'names': ['unknown', 'unknown'], 'dist face': 0.5970075162314712}
# {'status': 'ok', 'faces': [(295, 211, 402, 103), (375, 640, 464, 563)], 'names': ['manaf', 'unknown'], 'dist face': 0.5618947141010702}
# {'status': 'ok', 'faces': [(295, 211, 402, 103), (375, 640, 464, 563)], 'names': ['unknown', 'unknown'], 'dist face': 0.5700588618214149}
# {'status': 'ok', 'faces': [(375, 640, 464, 563), (295, 211, 402, 103)], 'names': ['unknown', 'manaf'], 'dist face': 0.5269188386017614}
# {'status': 'ok', 'faces': [(295, 223, 402, 115), (378, 640, 453, 577)], 'names': ['manaf', 'unknown'], 'dist face': 0.5866545649385669}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['manaf'], 'dist face': 0.4926206214607201}
# {'status': 'ok', 'faces': [(378, 640, 453, 569), (282, 239, 411, 110)], 'names': ['unknown', 'unknown'], 'dist face': 0.555761000531431}
# {'status': 'ok', 'faces': [(375, 640, 464, 563), (295, 235, 402, 127)], 'names': ['unknown', 'manaf'], 'dist face': 0.47062940172858614}
# {'status': 'ok', 'faces': [(387, 640, 461, 577)], 'names': ['unknown'], 'dist face': 0.5731011421873612}
# {'status': 'ok', 'faces': [(387, 640, 461, 577)], 'names': ['unknown'], 'dist face': 0.5748573459910983}
# {'status': 'ok', 'faces': [(387, 640, 461, 577)], 'names': ['unknown'], 'dist face': 0.5384445720526868}
# {'status': 'ok', 'faces': [(365, 640, 454, 554)], 'names': ['unknown'], 'dist face': 0.6824562593107888}
# {'status': 'ok', 'faces': [(378, 640, 453, 569)], 'names': ['unknown'], 'dist face': 0.6497119320989553}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['unknown'], 'dist face': 0.5407986017557485}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['manaf'], 'dist face': 0.5192469440332999}
# {'status': 'ok', 'faces': [(295, 211, 402, 103), (378, 640, 453, 577)], 'names': ['unknown', 'unknown'], 'dist face': 0.6373769071635316}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['manaf'], 'dist face': 0.5294294593934525}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['unknown'], 'dist face': 0.5634635783365118}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['unknown'], 'dist face': 0.5574337027155476}
# {'status': 'ok', 'faces': [(307, 223, 414, 115)], 'names': ['unknown'], 'dist face': 0.6213780906622797}
# {'status': 'ok', 'faces': [(315, 225, 405, 135), (365, 640, 454, 563)], 'names': ['unknown', 'unknown'], 'dist face': 0.6653210112449235}
# {'status': 'ok', 'faces': [(365, 640, 454, 554), (315, 235, 405, 145)], 'names': ['unknown', 'unknown'], 'dist face': 0.5611805990151524}
# {'status': 'ok', 'faces': [(295, 247, 402, 139)], 'names': ['unknown'], 'dist face': 0.5866575244367068}
# {'status': 'ok', 'faces': [(295, 235, 402, 127)], 'names': ['unknown'], 'dist face': 0.5491838743696406}
# {'status': 'ok', 'faces': [(305, 215, 395, 126)], 'names': ['unknown'], 'dist face': 0.559048975305834}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['manaf'], 'dist face': 0.4869415889135221}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['manaf'], 'dist face': 0.5082677942860367}
# {'status': 'ok', 'faces': [(283, 223, 390, 115)], 'names': ['manaf'], 'dist face': 0.4687356506928159}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(283, 199, 390, 91)], 'names': ['unknown'], 'dist face': 0.5348413573185933}
# {'status': 'ok', 'faces': [(283, 187, 390, 79)], 'names': ['unknown'], 'dist face': 0.5714658489268983}
# {'status': 'ok', 'faces': [(283, 187, 390, 79)], 'names': ['manaf'], 'dist face': 0.5278245798521232}
# {'status': 'ok', 'faces': [(283, 187, 390, 79)], 'names': ['manaf'], 'dist face': 0.48432020135450055}
# {'status': 'ok', 'faces': [(295, 199, 402, 91)], 'names': ['unknown'], 'dist face': 0.5385109828627151}
# {'status': 'ok', 'faces': [(295, 211, 402, 103)], 'names': ['unknown'], 'dist face': 0.5614760962156603}
# {'status': 'ok', 'faces': [(295, 223, 402, 115)], 'names': ['unknown'], 'dist face': 0.5641431550120217}
# {'status': 'ok', 'faces': [(295, 235, 402, 127)], 'names': ['unknown'], 'dist face': 0.5461553879700932}
# {'status': 'ok', 'faces': [(295, 259, 402, 151)], 'names': ['unknown'], 'dist face': 0.5892140333296325}
# {'status': 'ok', 'faces': [(315, 255, 405, 165)], 'names': ['manaf'], 'dist face': 0.513643806166683}
# {'status': 'ok', 'faces': [(315, 255, 405, 165)], 'names': ['unknown'], 'dist face': 0.5526680388445249}
# {'status': 'ok', 'faces': [(315, 255, 405, 165)], 'names': ['unknown'], 'dist face': 0.5839484185477196}
# {'status': 'ok', 'faces': [(307, 259, 414, 151)], 'names': ['unknown'], 'dist face': 0.5564720374840562}
# {'status': 'ok', 'faces': [(295, 247, 402, 139)], 'names': ['manaf'], 'dist face': 0.5123780514504416}
# {'status': 'ok', 'faces': [(295, 235, 402, 127)], 'names': ['unknown'], 'dist face': 0.5406310958915966}
# {'status': 'ok', 'faces': [(295, 235, 402, 127)], 'names': ['unknown'], 'dist face': 0.5360125160273725}
# {'status': 'ok', 'faces': [(283, 247, 390, 139)], 'names': ['unknown'], 'dist face': 0.5817641132866253}
# {'status': 'ok', 'faces': [(268, 282, 397, 153)], 'names': ['manaf'], 'dist face': 0.5021953136192215}
# {'status': 'ok', 'faces': [(271, 294, 378, 187)], 'names': ['manaf'], 'dist face': 0.5163434688132882}
# {'status': 'ok', 'faces': [(283, 318, 390, 211)], 'names': ['manaf'], 'dist face': 0.4975945785721524}
# {'status': 'ok', 'faces': [(295, 330, 402, 223)], 'names': ['unknown'], 'dist face': 0.5519857856104917}
# {'status': 'ok', 'faces': [(315, 325, 405, 235)], 'names': ['manaf'], 'dist face': 0.5197467413240998}
# {'status': 'ok', 'faces': [(315, 315, 405, 225)], 'names': ['unknown'], 'dist face': 0.5733488666413167}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.58096140787276}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5463085365322533}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['manaf'], 'dist face': 0.5295494335735119}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5835503226933907}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5484659090272579}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5485890622742445}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5484165381587002}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5349457141779217}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5627935063278304}
# {'status': 'ok', 'faces': [(315, 315, 405, 225)], 'names': ['manaf'], 'dist face': 0.5282731095308102}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['manaf'], 'dist face': 0.4742590684088771}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['manaf'], 'dist face': 0.48556420155252406}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5307823840615332}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['manaf'], 'dist face': 0.4721681239807588}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['manaf'], 'dist face': 0.4812146014448473}
# {'status': 'ok', 'faces': [(307, 330, 414, 223), (387, 640, 461, 569)], 'names': ['unknown', 'unknown'], 'dist face': 0.6328152091981021}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['manaf'], 'dist face': 0.5037012092564345}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5431068716695553}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(387, 640, 461, 569)], 'names': ['unknown'], 'dist face': 0.6395458386008375}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(387, 640, 461, 569)], 'names': ['unknown'], 'dist face': 0.6654509530065509}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 325, 405, 235)], 'names': ['manaf'], 'dist face': 0.5011509515534346}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 344, 405, 255)], 'names': ['manaf'], 'dist face': 0.4729384133738995}
# {'status': 'ok', 'faces': [(315, 325, 405, 235)], 'names': ['manaf'], 'dist face': 0.4790530875545261}
# {'status': 'ok', 'faces': [(307, 330, 414, 223), (378, 640, 453, 569)], 'names': ['manaf', 'unknown'], 'dist face': 0.6226957488759012}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['manaf'], 'dist face': 0.5168081364810785}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5775866659565682}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['unknown'], 'dist face': 0.5378291404271774}
# {'status': 'ok', 'faces': [(307, 342, 414, 235)], 'names': ['unknown'], 'dist face': 0.5579657031861058}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['manaf'], 'dist face': 0.49443914264874594}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['manaf'], 'dist face': 0.46771674537785013}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['unknown'], 'dist face': 0.5351710435523217}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['manaf'], 'dist face': 0.48788290412540314}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['unknown'], 'dist face': 0.5729599957734834}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.6167713445706596}
# {'status': 'ok', 'faces': [(319, 318, 426, 211)], 'names': ['manaf'], 'dist face': 0.5077932126006232}
# {'status': 'ok', 'faces': [(319, 318, 426, 211)], 'names': ['unknown'], 'dist face': 0.5621789170534789}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['manaf'], 'dist face': 0.5056753453687933}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5705340640041822}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5348014869907136}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5579210680906621}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5333126251426732}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.5374629852570726}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['manaf'], 'dist face': 0.5042843321639446}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['manaf'], 'dist face': 0.5222678095223441}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['unknown'], 'dist face': 0.5326404088708155}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['manaf'], 'dist face': 0.46983718715313616}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['unknown'], 'dist face': 0.5840222828972705}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['unknown'], 'dist face': 0.5528179425665197}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['unknown'], 'dist face': 0.5506718741986559}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(319, 318, 426, 211)], 'names': ['manaf'], 'dist face': 0.5276157129921698}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['manaf'], 'dist face': 0.5155397419589077}
# {'status': 'ok', 'faces': [(315, 295, 405, 205)], 'names': ['manaf'], 'dist face': 0.46335555711915244}
# {'status': 'ok', 'faces': [(325, 285, 415, 195)], 'names': ['manaf'], 'dist face': 0.49961315651822613}
# {'status': 'ok', 'faces': [(325, 275, 415, 185)], 'names': ['manaf'], 'dist face': 0.5167035322677744}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['manaf'], 'dist face': 0.47157104627067103}
# {'status': 'ok', 'faces': [(315, 315, 405, 225)], 'names': ['manaf'], 'dist face': 0.40626910320134463}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['manaf'], 'dist face': 0.4854577010995039}
# {'status': 'ok', 'faces': [(315, 305, 405, 215)], 'names': ['unknown'], 'dist face': 0.5729059106499075}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['manaf'], 'dist face': 0.49408214836890096}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['unknown'], 'dist face': 0.5317472811566685}
# {'status': 'ok', 'faces': [(325, 295, 415, 205)], 'names': ['manaf'], 'dist face': 0.5095507137398811}
# {'status': 'ok', 'faces': [(319, 306, 426, 199)], 'names': ['unknown'], 'dist face': 0.5485503383957815}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['unknown'], 'dist face': 0.5679761371080401}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['unknown'], 'dist face': 0.5428310140566113}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['unknown'], 'dist face': 0.5462554984234175}
# {'status': 'ok', 'faces': [(325, 305, 415, 215)], 'names': ['unknown'], 'dist face': 0.5794616705213317}
# {'status': 'ok', 'faces': [(335, 305, 425, 215)], 'names': ['unknown'], 'dist face': 0.5353654012827559}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 315, 405, 225)], 'names': ['manaf'], 'dist face': 0.45292429206454105}
# {'status': 'ok', 'faces': [(315, 305, 405, 215)], 'names': ['unknown'], 'dist face': 0.5366263184124895}
# {'status': 'ok', 'faces': [(315, 305, 405, 215)], 'names': ['manaf'], 'dist face': 0.5012729256295358}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['manaf'], 'dist face': 0.485857935460087}
# {'status': 'ok', 'faces': [(315, 305, 405, 215)], 'names': ['manaf'], 'dist face': 0.4819377535067585}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['manaf'], 'dist face': 0.47607501628123194}
# {'status': 'ok', 'faces': [(319, 318, 426, 211)], 'names': ['unknown'], 'dist face': 0.56737141194939}
# {'status': 'ok', 'faces': [(319, 318, 426, 211)], 'names': ['unknown'], 'dist face': 0.5415373442774659}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5805891103006733}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5877996225022027}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5755247950831484}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['unknown'], 'dist face': 0.6014294684335058}
# {'status': 'ok', 'faces': [(307, 318, 414, 211)], 'names': ['manaf'], 'dist face': 0.5223294116570598}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5558113826814665}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['manaf'], 'dist face': 0.5224863229771787}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['manaf'], 'dist face': 0.5047418219036087}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5686164800244574}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['manaf'], 'dist face': 0.5035548419342435}
# {'status': 'ok', 'faces': [(325, 344, 415, 255)], 'names': ['manaf'], 'dist face': 0.4984613005310973}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 344, 405, 255)], 'names': ['manaf'], 'dist face': 0.4770672932664424}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 335, 405, 245)], 'names': ['manaf'], 'dist face': 0.484360020918399}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 344, 405, 255)], 'names': ['manaf'], 'dist face': 0.49601166644426536}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(325, 335, 415, 245)], 'names': ['unknown'], 'dist face': 0.5394575843761286}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(315, 325, 405, 235)], 'names': ['manaf'], 'dist face': 0.5028422041872627}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5519327679517413}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5894745306157544}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5492212889709449}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['manaf'], 'dist face': 0.5148553065841196}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [], 'names': [], 'dist face': []}
# {'status': 'ok', 'faces': [(325, 315, 415, 225)], 'names': ['unknown'], 'dist face': 0.5598624457436057}
# {'status': 'ok', 'faces': [(319, 330, 426, 223)], 'names': ['unknown'], 'dist face': 0.5766268481798106}
# {'status': 'ok', 'faces': [(325, 325, 415, 235)], 'names': ['unknown'], 'dist face': 0.5788489093941782}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5738241309205435}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5894747370395038}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.5849076738622611}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['manaf'], 'dist face': 0.5166168526041571}
# {'status': 'ok', 'faces': [(307, 330, 414, 223)], 'names': ['unknown'], 'dist face': 0.6243718483678362}
# {'status': 'ok', 'faces': [(315, 315, 405, 225)], 'names': ['unknown'], 'dist face': 0.532329228736048}
# {'status': 'ok', 'faces': [(307, 306, 414, 199)], 'names': ['unknown'], 'dist face': 0.5515435440015409}
# {'status': 'ok', 'faces': [(295, 282, 402, 175)], 'names': ['unknown'], 'dist face': 0.5934209166584953}
# {'status': 'ok', 'faces': [(271, 270, 378, 163)], 'names': ['unknown'], 'dist face': 0.5400835854804089}
# {'status': 'ok', 'faces': [(254, 268, 383, 139)], 'names': ['unknown'], 'dist face': 0.560977921924637}
# {'status': 'ok', 'faces': [(254, 268, 383, 139)], 'names': ['unknown'], 'dist face': 0.5907568562452196}
# {'status': 'ok', 'faces': [(254, 268, 383, 139)], 'names': ['unknown'], 'dist face': 0.5996525104294518}
# {'status': 'ok', 'faces': [(254, 268, 383, 139)], 'names': ['unknown'], 'dist face': 0.566496571234634}
